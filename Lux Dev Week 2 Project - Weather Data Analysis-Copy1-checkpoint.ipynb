# %%
#importing the libraries required
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats
from scipy.stats import pearsonr

# %%
#import the data set
df=pd.read_csv(r"C:\Users\BOOTCAMP\OneDrive\Documents\Lux Dev\1. Weather Data.csv")

# %%
#Reviewing the 5 top and bottom rows of the data set
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# checking number of rows and column
df.shape
# Out:
# (8784, 8)

# %%
# checking the dat type
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
# checking for the data set information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
# checking for missing or null values in the data set
df.isnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# 1             False      False    False
# ...

# %%
# checking for missing or null values in the data set
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
# checking for duplicates values in the data set
df.duplicated().sum()
# Out:
# 0

# %%
#Statistical Summary for all the features - including the mean, standard deviation, etc
df.describe(include = "all")
# Out:
#             Date/Time       Temp_C  Dew Point Temp_C    Rel Hum_%  \
# count            8784  8784.000000       8784.000000  8784.000000
# unique           8784          NaN               NaN          NaN
# top     1/1/2012 0:00          NaN               NaN          NaN
# freq                1          NaN               NaN          NaN
# mean              NaN     8.798144          2.555294    67.431694
# std               NaN    11.687883         10.883072    16.918881
# min               NaN   -23.300000        -28.500000    18.000000
# 25%               NaN     0.100000         -5.900000    56.000000
# 50%               NaN     9.300000          3.300000    68.000000
# 75%               NaN    18.800000         11.800000    81.000000
# max               NaN    33.000000         24.400000   100.000000
#
#         Wind Speed_km/h  Visibility_km    Press_kPa       Weather
# count       8784.000000    8784.000000  8784.000000          8784
# ...

# %%
# Statistical Summary for numerical features only
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
# Checking for any outliers using a Box PLot
# Using the function value_counts to categorize the feature "Weather"
Weather_counts=df["Weather"].value_counts()
Weather_counts
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#Weather_counts=df["Weather"].value_counts()
#Weather_counts
sns.boxplot(x = "Weather", y = "Rel Hum_%", data = df)
#<Axes: xlabel='Visibility_km', ylabel='Rel Hum_%'>
# Out:
# <AxesSubplot:xlabel='Weather', ylabel='Rel Hum_%'>

# %%
#It was observed that the feature "Weather" that happens to be the only categorical variable has too many categories that makes the box plot not easily understood. it will be reduced to manageable number of categories later in the project.

# %%
sns.boxplot(x = "Visibility_km", y = "Rel Hum_%", data = df)
#<Axes: xlabel='Visibility_km', ylabel='Rel Hum_%'>
# Out:
# <AxesSubplot:xlabel='Visibility_km', ylabel='Rel Hum_%'>

# %%
#Data Visualization
# To Visualise key parameters distribution between Visibility_km and Dew Point Temp_C using scatter plot
y = df["Visibility_km"]
x = df["Dew Point Temp_C"]
plt.scatter(x,y)
plt.title("Scatter Plot of Engine Visibility_km vs Dew Point Temp_C")
plt.xlabel("Dew Point Temp_C")
plt.ylabel("Visibility_km")
# Out:
# Text(0, 0.5, 'Visibility_km')

# %%
#Wind Speed_km/h
#Temp_C
y = df["Rel Hum_%"]
x = df["Temp_C"]
plt.scatter(x,y)
plt.title("Scatter Plot of Rel Hum_% vs Temp_C")
plt.xlabel("Temp_C")
plt.ylabel("Rel Hum_%")
# Out:
# Text(0, 0.5, 'Rel Hum_%')

# %%
#From the scatter plot, we see that as the temperature goes up, the Rel Hum_% also goes up. This is giving us an initial indication that there is a positive linear relationship between these two variables.

# %%
# Wind Speed_km/h
y = df["Wind Speed_km/h"]
x = df["Temp_C"]
plt.scatter(x,y)
plt.title("Scatter Plot of Wind Speed_km/hvs Temp_C")
plt.xlabel("Temp_C")
plt.ylabel("Wind Speed_km/h")
# Out:
# Text(0, 0.5, 'Wind Speed_km/h')

# %%
# GroupBy
df_1 = df[["Rel Hum_%", "Weather"]]
df_1.head()
# Out:
#    Rel Hum_% Weather
# 0         86     Fog
# 1         87     Fog
# 2         89     Fog
# 3         88     Fog
# 4         88     Fog

# %%
# The "Weather" column is the closest to a categorical variable, but the categories are to many
# I will take the liberty to alter the data set to make it USEABLE by replacing values under the WEATHER Column to a maximum of 20 categories.
# Replace values using a dictionary
df = df.replace({'Weather': {"Thunderstorms,Rain,Fog": "Drizzle", "Rain,Ice Pellets": "Rain","Rain Showers,Fog" : "Fog","Rain,Snow Grains": "Snow","Thunderstorms,Heavy Rain Showers" : "Fog","Thunderstorms,Moderate Rain Showers,Fog": "Fog","Freezing Rain,Snow Grains": "Rain","Freezing Rain,Ice Pellets,Fog": "Fog","Drizzle,Snow" : "Snow","Thunderstorms" : "Rain","Moderate Snow,Blowing Snow"  : "Snow","Freezing Drizzle,Haze": "Cloudy","Rain,Haze"  : "Rain","Thunderstorms,Rain Showers,Fog" : "Rain","Thunderstorms,Rain": "Fog","Rain,Snow,Ice Pellets": "Fog","Freezing Fog": "Fog","Freezing Rain,Fog": "Fog","Snow Showers,Fog": "Fog","Moderate Snow": "Snow","Snow,Haze": "Snow","Snow,Ice Pellets" : "Snow","Freezing Drizzle,Fog": "Fog","Freezing Drizzle": "Rain", "Freezing Drizzle,Snow": "Snow","Freezing Rain": "Rain","Drizzle,Snow,Fog": "Fog","Haze": "Fog","Thunderstorms,Rain Showers": "Rain","Rain,Snow": "Snow"}})

# %%
df[["Weather"]].value_counts()
# Out:
# Weather
# Mainly Clear                 2106
# Mostly Cloudy                2069
# Cloudy                       1731
# Clear                        1326
# Snow                          439
# Rain                          353
# Fog                           210
# Rain Showers                  188
# Rain,Fog                      116
# Drizzle,Fog                    80
# Snow Showers                   60
# Drizzle                        42
# Snow,Fog                       37
# Snow,Blowing Snow              19
# Freezing Rain,Haze              2
# Rain Showers,Snow Showers       2
# Moderate Rain,Fog               1
# Drizzle,Ice Pellets,Fog         1
# Rain,Snow,Fog                   1
# Snow Pellets                    1
# dtype: int64

# %%
#df_1grp = df_1.groupby(["Weather"], as_index = False).mean()
#df_1grp
# Out:
#                       Weather  Rel Hum_%
# 0                       Clear  64.497738
# 1                      Cloudy  69.614096
# 2                     Drizzle  88.238095
# 3                 Drizzle,Fog  93.275000
# 4     Drizzle,Ice Pellets,Fog  92.000000
# 5                         Fog  91.390476
# 6          Freezing Rain,Haze  82.500000
# 7                Mainly Clear  60.667142
# 8           Moderate Rain,Fog  94.000000
# 9               Mostly Cloudy  62.102465
# 10                       Rain  83.776204
# 11               Rain Showers  75.159574
# 12  Rain Showers,Snow Showers  76.500000
# 13                   Rain,Fog  93.189655
# 14              Rain,Snow,Fog  96.000000
# 15                       Snow  80.195900
# 16               Snow Pellets  59.000000
# 17               Snow Showers  72.350000
# 18          Snow,Blowing Snow  84.473684
# 19                   Snow,Fog  90.675676

# %%
df_2 = df[["Weather", "Rel Hum_%"]]
df_2.head()
# Out:
#   Weather  Rel Hum_%
# 0     Fog         86
# 1     Fog         87
# 2     Fog         89
# 3     Fog         88
# 4     Fog         88

# %%
df_2grp = df_2.groupby(["Weather"], as_index = False).mean()
df_2grp
# Out:
#                       Weather  Rel Hum_%
# 0                       Clear  64.497738
# 1                      Cloudy  69.614096
# 2                     Drizzle  88.238095
# 3                 Drizzle,Fog  93.275000
# 4     Drizzle,Ice Pellets,Fog  92.000000
# 5                         Fog  91.390476
# 6          Freezing Rain,Haze  82.500000
# 7                Mainly Clear  60.667142
# 8           Moderate Rain,Fog  94.000000
# 9               Mostly Cloudy  62.102465
# 10                       Rain  83.776204
# 11               Rain Showers  75.159574
# 12  Rain Showers,Snow Showers  76.500000
# 13                   Rain,Fog  93.189655
# 14              Rain,Snow,Fog  96.000000
# 15                       Snow  80.195900
# 16               Snow Pellets  59.000000
# 17               Snow Showers  72.350000
# 18          Snow,Blowing Snow  84.473684
# 19                   Snow,Fog  90.675676

# %%
df[["Temp_C"]].value_counts()
# Out:
# Temp_C
#  16.6     65
#  1.1      58
#  0.8      47
#  1.5      45
#  19.3     44
#           ..
# -19.5      1
# -19.6      1
# -19.9      1
# -20.0      1
# -23.3      1
# Length: 533, dtype: int64

# %%
df_test = df[["Weather", "Temp_C", "Rel Hum_%"]]
df_test.head()
# Out:
#   Weather  Temp_C  Rel Hum_%
# 0     Fog    -1.8         86
# 1     Fog    -1.8         87
# 2     Fog    -1.8         89
# 3     Fog    -1.5         88
# 4     Fog    -1.5         88

# %%
#I then group the  data according to Weather and Temperature in the second line. Since we are interested in knowing how the average Relative humidity across the board, we can take the mean of each group and append at this bit at the very end of the next line of code

df_grp = df_test.groupby(["Weather", "Temp_C"], as_index = False).mean()
df_grp
# Out:
#        Weather  Temp_C  Rel Hum_%
# 0        Clear   -23.3       62.0
# 1        Clear   -19.2       67.0
# 2        Clear   -19.1       69.0
# 3        Clear   -18.7       67.0
# 4        Clear   -18.5       66.0
# ...        ...     ...        ...
# 2633  Snow,Fog     0.6       95.0
# 2634  Snow,Fog     0.7       96.0
# 2635  Snow,Fog     0.8       95.5
# 2636  Snow,Fog     1.0       88.0
# 2637  Snow,Fog     1.1       96.0
#
# [2638 rows x 3 columns]

# %%
df[['Rel Hum_%', 'Temp_C']]
# Out:
#       Rel Hum_%  Temp_C
# 0            86    -1.8
# 1            87    -1.8
# 2            89    -1.8
# 3            88    -1.5
# 4            88    -1.5
# ...         ...     ...
# 8779         81     0.1
# 8780         83     0.2
# 8781         93    -0.5
# 8782         89    -0.2
# 8783         86     0.0
#
# [8784 rows x 2 columns]

# %%
# Carrying out a pivoting process for better visuals
df_pivot = df_grp.pivot(index = "Weather", columns = "Temp_C")
df_pivot
# Out:
#                           Rel Hum_%                                            \
# Temp_C                        -23.3 -23.2 -22.8 -22.2 -21.4 -21.3 -21.2 -21.1
# Weather
# Clear                          62.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Cloudy                          NaN   NaN   NaN   NaN  63.0   NaN  61.0  61.0
# Drizzle                         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Drizzle,Fog                     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Drizzle,Ice Pellets,Fog         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Fog                             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Freezing Rain,Haze              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Mainly Clear                    NaN   NaN  62.0  60.0   NaN   NaN   NaN   NaN
# Moderate Rain,Fog               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Mostly Cloudy                   NaN  62.0   NaN   NaN   NaN  63.0   NaN   NaN
# ...

# %%
df_pivot = df_grp.pivot(index = "Rel Hum_%", columns = "Temp_C")
df_pivot

# %%
# Using  A Heat MAp to visualise 
plt.pcolor(df_pivot, cmap="RdBu")
plt.colorbar()
plt.show()

# %%
# Checking Correlation between different variables

sns.regplot(x = "Temp_C", y = "Rel Hum_%", data = df)
plt.ylim(0,)
# Out:
# (0.0, 104.1)

# %%
#As we can see in this plot, when  Temperature value goes up, the value of relative humidity goes down. Therefore, there is a negative linear relationship between Temperature and Relative Humidity. These two variables are said to have a negative correlation.

# %%
sns.regplot(x = "Visibility_km", y = "Temp_C", data = df)
plt.ylim(0,)
# Out:
# (0.0, 35.815)

# %%
#In this plot, the straight line through the data points is not steep, which shows that there is a positive linear relationship between the two variables.

#With increased temperature values, visibility increses as well, and the slope of the line is positive. So there is a positive correlation between Temperature and visibility.

# %%
#Correlation Statistics
# looking at the correlation between the variables visibility and Relative Humidity.

# Remove rows with NaN or infinite values
#df_cleaned = df[["Visibility_km", "Rel Hum_%"]].dropna()
#df_cleaned = df_cleaned[np.isfinite(df_cleaned).all(1)]

# Calculate Pearson correlation
#pearson_coef, p_value = stats.pearsonr(df_cleaned["Visibility_km"], df_cleaned["Rel Hum_%"])
#pearson_coef, p_value

df_cleaned = df[["Visibility_km", "Rel Hum_%"]].dropna()
df_cleaned = df_cleaned[np.isfinite(df_cleaned).all(1)]

# Calculate Pearson correlation
pearson_coef, p_value = stats.pearsonr(df_cleaned["Visibility_km"], df_cleaned["Rel Hum_%"])
pearson_coef, p_value
# Out:
# (-0.633683184153737, 0.0)

# %%
#Taking all variables into account, we can now create a heat map that indicates the correlation between each of the variables with one another.


df_numeric = df.select_dtypes(include=[float, int])
corr_matrix = df_numeric.corr()
corr_matrix
# Out:
#                     Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Temp_C            1.000000          0.932714  -0.220182        -0.061876
# Dew Point Temp_C  0.932714          1.000000   0.139494        -0.095685
# Rel Hum_%        -0.220182          0.139494   1.000000        -0.092743
# Wind Speed_km/h  -0.061876         -0.095685  -0.092743         1.000000
# Visibility_km     0.273455          0.050813  -0.633683         0.004883
# Press_kPa        -0.236389         -0.320616  -0.231424        -0.356613
#
#                   Visibility_km  Press_kPa
# Temp_C                 0.273455  -0.236389
# Dew Point Temp_C       0.050813  -0.320616
# Rel Hum_%             -0.633683  -0.231424
# Wind Speed_km/h        0.004883  -0.356613
# Visibility_km          1.000000   0.231847
# Press_kPa              0.231847   1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
#The color scheme indicates the Pearson correlation coefficient, indicating the strength of the correlation between two variables. We can see a diagonal line with a dark red color indicating that all the values on this diagonal are highly correlated. This makes sense because when you look closer, the values on the diagonal are the correlation of all variables with themselves, which will be always one. This correlation heat map gives us a good overview of how the different variables are related to one another, and most importantly, how these variables are related to Temperature.
